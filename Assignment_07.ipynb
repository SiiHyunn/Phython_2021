# %%
class Counter:
    def __init__(self, number = 0):
        if(number>=100):
            self.__number = 0
        elif(number<=-1):
            self.__number = 0
        else:
            self.__number = number
        
    def reset(self):
        self.__number = 0
        
    def inc(self):
        self.__number += 1
        
    def dec(self):
        self.__number -= 1
        
    def __str__(self):
        return 'C({})'.format(self.__number)
    
    def __add__(self, other):
        return Counter(self.__number + other.__number)
    
    def __sub__(self, other):
        return Counter(self.__number - other.__number)
    
c1 = Counter(10)
c1.inc()
print('c1 =', c1, '\n')

c2 = Counter()
c2.inc()
c2.inc()
c2.dec()
print('c2 =', c2)
c2.reset()
print('c2 =', c2, '\n')

c1 = Counter(10)
c2 = Counter(20)
c3 = c1 + c2
c4 = c1 - c2
print('c3 =', c3)
print('c4 =', c4)
# Out:
# c1 = C(11)
#
# c2 = C(1)
# c2 = C(0)
#
# c3 = C(30)
# c4 = C(0)

# %%
class Student:
    def __init__(self, name, student_id, korean_quiz = 0, math_quiz = 0, science_quiz = 0, total_quiz = 0):
        self.__name = name
        self.__student_id = student_id
        self.__korean_quiz = korean_quiz
        self.__math_quiz = math_quiz
        self.__science_quiz = science_quiz
        self.__total_quiz = total_quiz
        
    def set_korean_quiz(self, korean_quiz):
        self.__korean_quiz = korean_quiz
    
    def set_math_quiz(self, math_quiz):
        self.__math_quiz = math_quiz
        
    def set_science_quiz(self, science_quiz):
        self.__science_quiz = science_quiz
    
    def get_name(self):
        return self.__name
    
    def get_student_id(self):
        return self.__student_id
    
    def get_korean_quiz(self):
        return self.__korean_quiz
    
    def get_math_quiz(self):
        return self.__math_quiz
    
    def get_science_quiz(self):
        return self.__science_quiz
    
    def get_total_score(self):
        return self.__korean_quiz + self.__math_quiz + self.__science_quiz
    
    def get_avg_score(self):
        return '{}'.format((self.__korean_quiz + self.__math_quiz + self.__science_quiz)/3)
        
    def __str__(self):
        return '이름 : {}, 학번 : {}\n국어성적 : {}, 수학성적 : {}, 과학성적 : {}\n합계 : {}, 평균 : {}'.format(
            self.get_name(), self.get_student_id(), self.get_korean_quiz(), self.get_math_quiz(), 
            self.get_science_quiz(), self.get_total_score(), self.get_avg_score())
            
name = input('학생의 이름을 입력하세요 : ')
student_id = input('학생의 학번을 입력하세요 : ')

student = Student(name, student_id)

korean_quiz = int(input('학생의 국어 성적을 입력하세요 : '))
math_quiz = int(input('학생의 수학 성적을 입력하세요 : '))
science_quiz = int(input('학생의 과학 성적을 입력하세요 : '))
student.set_korean_quiz(korean_quiz)
student.set_math_quiz(math_quiz)
student.set_science_quiz(science_quiz)
print(student)
# Out:
# 학생의 이름을 입력하세요 : 홍길동
# 학생의 학번을 입력하세요 : 20200012
# 학생의 국어 성적을 입력하세요 : 85
# 학생의 수학 성적을 입력하세요 : 90
# 학생의 과학 성적을 입력하세요 : 95
# 이름 : 홍길동, 학번 : 20200012
# 국어성적 : 85, 수학성적 : 90, 과학성적 : 95
# 합계 : 270, 평균 : 90.0

# %%
class TV:
    MIN_VOLUME = 0
    MAX_VOLUME = 20
    MIN_CHANNEL = 0
    MAX_CHANNEL = 200
    
    def __init__(self, volume=5, channel=0, is_on = False):
        self.__volume = volume
        self.__channel = channel
        self.__is_on = is_on
        
    def __str__(self):
        if(self.__is_on == False):
            return 'TV가 꺼짐 상태입니다.'
        else:
            return '볼륨 = {}, 채널 = {}'.format(self.__volume, self.__channel)
        
    def toggle_power(self):
        if(self.__is_on == False):
            self.__is_on = True
        else:
            self.__is_on == False
            self.__volume = 5
            self.__channel = 0
            
    def get_channel(self):
        return self.__channel
    
    def set_channel(self, channel):
        self.__channel = channel
        
    def get_volume(self):
        return self.__volume
    
    def set_volume(self, volume):
        self.__volume = volume
        
    def volume_up(self):
        self.__volume += 1
        
    def volume_down(self):
        self.__volume -= 1
        
    def channel_up(self):
        self.__channel += 1
        
    def channel_down(self):
        self.__channel -= 1
        
        
my_tv = TV()
print(my_tv)
my_tv.toggle_power()
print(my_tv)
my_tv.set_channel(45)
print(my_tv)
my_tv.volume_up()
my_tv.channel_up()
print(my_tv)
# Out:
# TV가 꺼짐 상태입니다.
# 볼륨 = 5, 채널 = 0
# 볼륨 = 5, 채널 = 45
# 볼륨 = 6, 채널 = 46

# %%
class Rectangle:
    def __init__(self, x, y, width, height):
        self.__x = x
        self.__y = y
        self.__width = width
        self.__height = height
        
    def __str__(self):
        return 'Rectangle : (x = {}, y = {}, w = {}, h = {}), 면적 : {}'.format(
            self.__x, self.__y, self.__width, self.__height,self.area())
        
    def get_x(self):
        return self.__x
    
    def set_channel(self, x):
        self.__x = x
        
    def get_y(self):
        return self.__y
    
    def set_y(self, y):
        self.__y = y
        
    def get_width(self):
        return self.__width
    
    def set_width(self, width):
        self.__width = width
        
    def get_height(self):
        return self.__height
    
    def set_height(self, height):
        self.__height = height
        
    def area(self):
        return self.__height * self.__width
    
    def overlaps(self, r):
        if (self.__x>(r.__x+r.__width)) or ((self.__x+self.__width)<r.__x) or 
        ((self.__y+self.__height)<r.__y) or (self.__y>(r.__y+r.__height)):
            return 'False'
        else:
            return 'True'
    def contains(self, r):
        if (((r.__width - r.__x)>= (self.__width - self.__x)) or ((r.__height - r.__y)>= (self.__height - self.__y)) and 
            ((r.__width-r.__x)<=(self.__width)) and ((r.__height-r.__y)<=(self.__height))):
            return 'False'
        else:
            return 'True'
        
r1 = Rectangle(0, 0, 100, 100)
r2 = Rectangle(0, -10, 10, 10)
r3 = Rectangle(-100, 0, 120, 100)

print('r1 =', r1)
print('r2 =', r2)
print('r3 =', r3)

print('r1 contains r2 :', r1.contains(r2))
print('r1 contains r3 :', r1.contains(r3))
print('r1 overlaps r2 :', r1.overlaps(r2))
print('r1 overlaps r3 :', r1.overlaps(r3))
# Out:
# r1 = Rectangle : (x = 0, y = 0, w = 100, h = 100), 면적 : 10000
# r2 = Rectangle : (x = 0, y = -10, w = 10, h = 10), 면적 : 100
# r3 = Rectangle : (x = -100, y = 0, w = 120, h = 100), 면적 : 12000
# r1 contains r2 : True
# r1 contains r3 : False
# r1 overlaps r2 : True
# r1 overlaps r3 : True
